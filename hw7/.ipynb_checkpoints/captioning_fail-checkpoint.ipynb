# %% [markdown]
# <h1 align="center">First of all -- Checking Questions</h1>
#
# **Вопрос 1**: Можно ли использовать сверточные сети для классификации текстов? Если нет обоснуйте :D, если да то как? как решить проблему с произвольной длинной входа?
#
# ну bag of words и вперед, к сверткам)
#
# **Вопрос 2**: Чем LSTM лучше/хуже чем обычная RNN?
#
# За счет того, что LSTM имеет forget и output (скорее даже output) gate'ы она может научиться помнить важную информацию с дальних слоев.
# Если бы forget gate равнялся бы единице всегда, то получились бы resnet-подобные шорткаты, что вроде хорошо.
# Поэтому она вроде как лучше работает, помогает бороться с затухающими градиентами
#
# Хуже -- хммм, ну, наверное, дольше учится, сложнее понимается.
#
# **Вопрос 3**:  Выпишите производную $\frac{d c_{n+1}}{d c_{k}}$ для LSTM http://colah.github.io/posts/2015-08-Understanding-LSTMs/, объясните формулу, когда производная затухает, когда взрывается?
#
# ну не, сложна
#
# **Вопрос 4**: Зачем нужен TBPTT почему BPTT плох?
#
# в BPTT могут взрываться градиенты. TBPTT решает эту проблему)
#
#
# **Вопрос 5**: Как комбинировать рекуррентные и сверточные сети, а главное зачем? Приведите несколько примеров реальных задач.
#
# Как -- можно выход сверточной сети (не софтмакс, а какие-нибудь активации) подсовывать на разные итерации рекуррентной -- при инициализации hidden layer'a или приплюсовывать каждый раз к hidden layer у, или еще как нибудь.
#
# Примеры задач:
#
# * image <anything> (captioning, segmentation, ...)
# * video <anything> (caption, segmentation, ...)
#
# короче, когда нам захочется сунуть как вход не само изображение, а его крутое описание с последних слоев глубокой сверточной сети.
#
# **Вопрос 6**: Объясните интуицию выбора размера эмбединг слоя? почему это опасное место?
#
# Ну, я брал примерно корень)
#
# Ну надо прикинуть сколько информации примерно несет единичка в one hot encoding. Ну, примерно логарифм (позиция единички). Но поскольку нейросеть (а точнее линейная модель) не столь умная, давайте ей дадим чуть больше места.
#
# Как бывший олимпиадный программист, считаю, что после логарифма идет либо лог-квардат, либо корень, что на на самом деле примерно одно и то же (на данных наших порядков)

# %% [markdown]
# * Arseniy Ashuha, you can text me ```ars.ashuha@gmail.com```, Александр Панин
#
# <h1 align="center"> Image Captioning </h1>
#
# In this seminar you'll be going through the image captioning pipeline. It can help u https://ars-ashuha.ru/slides/2016.11.11_ImageCaptioning/image_captionong.pdf
#
# To begin with, let us download the dataset of image features from a pre-trained GoogleNet.

# %%
# !wget https://www.dropbox.com/s/d50pqlm19c6f6w5/data.tar.gz?dl=0 -O data.tar.gz
# !tar -xvzf data.tar.gz
# Out:
# data/caption_tokens.pcl
# data/
# data/image_codes.npy
# data/raw_captions.pcl
# data/Dog-and-Cat.jpg
# data/blvc_googlenet.pkl

# %% [markdown]
# ### Data preprocessing

# %%
# %%time
# Read Dataset
import numpy as np
import pickle

img_codes = np.load("data/image_codes.npy")
captions = pickle.load(open('data/caption_tokens.pcl', 'rb'))
# Out:
# CPU times: user 576 ms, sys: 348 ms, total: 924 ms
# Wall time: 803 ms

# %%
print("each image code is a 1000-unit vector:", img_codes.shape)
print(img_codes[0,:10])
print('\n\n')
print("for each image there are 5-7 descriptions, e.g.:\n")
print('\n'.join(captions[0]))
# Out:
# each image code is a 1000-unit vector: (123287, 1000)
# [ 1.38901556 -3.82951474 -1.94360816 -0.5317238  -0.03120959 -2.87483215
#  -2.9554503   0.6960277  -0.68551242 -0.7855981 ]
#
#
#
# for each image there are 5-7 descriptions, e.g.:
#
# a man with a red helmet on a small moped on a dirt road
# man riding a motor bike on a dirt road on the countryside
# a man riding on the back of a motorcycle
# a dirt path with a young person on a motor bike rests to the foreground of a verdant area with a bridge and a background of cloud wreathed mountains
# a man in a red shirt and a red hat is on a motorcycle on a hill side

# %%
#split descriptions into tokens
for img_i in range(len(captions)):
    for caption_i in range(len(captions[img_i])):
        sentence = captions[img_i][caption_i] 
        captions[img_i][caption_i] = ["#START#"]+sentence.split(' ')+["#END#"]

# %%
from itertools import chain
words = list(chain.from_iterable(chain.from_iterable(captions)))

# %%
from collections import Counter

# %%
# Build a Vocabulary

############# TO CODE IT BY YOURSELF ##################
word_counts = dict(Counter(words))

vocab  = ['#UNK#', '#START#', '#END#']
vocab += [k for k, v in word_counts.items() if v >= 5]
n_tokens = len(vocab)

assert(10000 <= n_tokens <= 10500)

word_to_index = {w: i for i, w in enumerate(vocab)}

# %%
PAD_ix = -1
UNK_ix = vocab.index('#UNK#')

def as_matrix(sequences,max_len=None):
    max_len = max_len or max(map(len,sequences))
    
    matrix = np.zeros((len(sequences),max_len),dtype='int32')+PAD_ix
    for i,seq in enumerate(sequences):
        row_ix = [word_to_index.get(word,UNK_ix) for word in seq[:max_len]]
        matrix[i,:len(row_ix)] = row_ix
    
    return matrix

# %%
#try it out on several descriptions of a random image
as_matrix(captions[1337])
# Out:
# array([[ 5290,   739,  6557,  9771,  6858,  8793,   293,  9104,  1974,
#          3314,  8388,  7624,  4510,    -1,    -1],
#        [ 5290,  1974,  3314,  9564,  3129,  6820,  7624,  8388,   441,
#         10124,   293,  4510,    -1,    -1,    -1],
#        [ 5290,  5695,  9771,  6858,  8793,   293,  9104,  1974,  2571,
#          8375,  8773,  7034,  8871,  7035,  4510],
#        [ 5290,  5695,   178,  9905,  9684,  6792,  5695,   178,  6816,
#          4510,    -1,    -1,    -1,    -1,    -1],
#        [ 5290,   739,  6557,  9771,  6858,  8793,   293,  9104,  1974,
#          3314,  8773,  7034,  9534,  4510,    -1]], dtype=int32)

# %% [markdown]
# ### Mah Neural Network

# %%
# network shapes. 
CNN_FEATURE_SIZE = img_codes.shape[1]
EMBED_SIZE = 250 #pls change me if u want
LSTM_UNITS = 1000 #pls change me if u want

# %%
import theano
import lasagne
import theano.tensor as T
from lasagne.layers import *
import lasagne.layers.dnn as lld

# %%
# Input Variable
sentences = T.imatrix()# [batch_size x time] of word ids
image_vectors = T.matrix() # [batch size x unit] of CNN image features
sentence_mask = T.neq(sentences, PAD_ix)

# %%
from lasagne import layers as ll

# %%
#network inputs
l_words = InputLayer((None, None), sentences)
l_mask = InputLayer((None, None), sentence_mask)

#embeddings for words 
############# TO CODE IT BY YOURSELF ##################
l_word_embeddings = lasagne.layers.EmbeddingLayer(l_words, input_size=n_tokens, output_size=EMBED_SIZE)

# %%
# input layer for image features
l_image_features = InputLayer((None, CNN_FEATURE_SIZE), image_vectors)

############# TO CODE IT BY YOURSELF ##################
#convert 1000 image features from googlenet to whatever LSTM_UNITS you have set
#it's also a good idea to add some dropout here and there
l_image_features_small = ll.DropoutLayer(l_image_features) #<Apply Dropout Layer to regularise your Net>
l_image_features_small = ll.DenseLayer(l_image_features_small, num_units=LSTM_UNITS)
assert l_image_features_small.output_shape == (None, LSTM_UNITS)

# %%
############# TO CODE IT BY YOURSELF ##################
# Concatinate image features and word embedings in one sequence 


l_forward_1 = lasagne.layers.LSTMLayer(l_word_embeddings, num_units=LSTM_UNITS, cell_init=l_image_features_small)
l_backward_1 = lasagne.layers.LSTMLayer(l_word_embeddings, num_units=LSTM_UNITS, cell_init=l_image_features_small,
                                        backwards=True)
l_recurrent_1 = ElemwiseSumLayer([l_forward_1, l_backward_1])

l_forward_2 = lasagne.layers.LSTMLayer(l_recurrent_1, num_units=300)
l_backward_2 = lasagne.layers.LSTMLayer(l_recurrent_1, num_units=300, backwards=True)
l_recurrent_2 = ElemwiseSumLayer([l_forward_2, l_backward_2])

decoder = l_recurrent_2

# decoder = LSTMLayer(l_word_embeddings,
#                     num_units=LSTM_UNITS,
#                     cell_init=l_image_features_small,
#                     mask_input=l_mask,
#                     grad_clipping=100)
# decoder = LSTMLayer(decoder,
#                     num_units=LSTM_UNITS,
#                     mask_input=l_mask,
#                     grad_clipping=100, backwards=False)

# %%
# Decoding of rnn hiden states
from broadcast import BroadcastLayer,UnbroadcastLayer

#apply whatever comes next to each tick of each example in a batch. Equivalent to 2 reshapes
broadcast_decoder_ticks = BroadcastLayer(decoder, (0, 1))
print("broadcasted decoder shape = ",broadcast_decoder_ticks.output_shape)

predicted_probabilities_each_tick = DenseLayer(
    broadcast_decoder_ticks,n_tokens, nonlinearity=lasagne.nonlinearities.softmax)

#un-broadcast back into (batch,tick,probabilities)
predicted_probabilities = UnbroadcastLayer(
    predicted_probabilities_each_tick, broadcast_layer=broadcast_decoder_ticks)

print("output shape = ", predicted_probabilities.output_shape)

#remove if you know what you're doing (e.g. 1d convolutions or fixed shape)
assert predicted_probabilities.output_shape == (None, None, 10373)
# Out:
# broadcasted decoder shape =  (None, 300)
# output shape =  (None, None, 10373)

# %%
next_word_probas = get_output(predicted_probabilities)

reference_answers = sentences[:,1:]
output_mask = sentence_mask[:,1:]

#write symbolic loss function to train NN for
loss = lasagne.objectives.categorical_crossentropy(
    next_word_probas[:, :-1].reshape((-1, n_tokens)),
    reference_answers.reshape((-1,))
).reshape(reference_answers.shape)

############# TO CODE IT BY YOURSELF ##################
loss = loss[output_mask.nonzero()].mean()

# %%
#trainable NN weights
############# TO CODE IT BY YOURSELF ##################
eta = theano.shared(lasagne.utils.floatX(1e-3))
weights = lasagne.layers.get_all_params(predicted_probabilities, trainable=True)
updates = lasagne.updates.adam(loss, weights, learning_rate=eta)

# %%
#compile a function that takes input sentence and image mask, outputs loss and updates weights
#please not that your functions must accept image features as FIRST param and sentences as second one
############# TO CODE IT BY YOURSELF ##################
train_step = theano.function([image_vectors, sentences], loss, updates=updates, allow_input_downcast=True)
val_step   = theano.function([image_vectors, sentences], loss, allow_input_downcast=True)

# %% [markdown]
# # Training
#
# * You first have to implement a batch generator
# * Than the network will get trained the usual way

# %%
captions = np.array(captions)

# %%
from random import choice

def generate_batch(images,captions,batch_size,max_caption_len=None):
    #sample random numbers for image/caption indicies
    random_image_ix = np.random.randint(0, len(images), size=batch_size)
    
    #get images
    batch_images = images[random_image_ix]
    
    #5-7 captions for each image
    captions_for_batch_images = captions[random_image_ix]
    
    #pick 1 from 5-7 captions for each image
    batch_captions = list(map(choice, captions_for_batch_images))
    
    #convert to matrix
    batch_captions_ix = as_matrix(batch_captions,max_len=max_caption_len)
    
    return batch_images, batch_captions_ix

# %%
generate_batch(img_codes,captions, 3)
# Out:
# (array([[-2.3889904 ,  0.82507211, -0.30270797, ..., -1.50596011,
#           0.5586465 ,  0.51387995],
#         [ 0.0089069 ,  0.52352536,  1.81403351, ..., -0.56861961,
#          -0.49657369, -2.44582129],
#         [ 3.99679136, -2.20860839,  3.59302354, ...,  1.84818053,
#          -0.18092972,  4.8614397 ]], dtype=float32),
#  array([[5290, 5695, 3158, 9104,  480, 9905, 4718, 8871, 7035, 4510,   -1,
#            -1,   -1],
#         [5290, 5695, 7465, 3122, 3653, 3579, 2597, 5930, 5695, 3698, 2304,
#          4510,   -1],
#         [5290, 5695, 5571, 6530, 8388, 1943, 6634, 8775,  453,   29, 3932,
#          8493, 4510]], dtype=int32))

# %% [markdown]
# ### Main loop
# * We recommend you to periodically evaluate the network using the next "apply trained model" block
#  *  its safe to interrupt training, run a few examples and start training again

# %%
batch_size = 300 #adjust me
n_epochs   = 1000 #adjust me
n_batches_per_epoch = 10 #adjust me
n_validation_batches = 5 #how many batches are used for validation after each epoch

# %%
eta.set_value(lasagne.utils.floatX(eta.get_value() * 0 + 1e-3))

# %%
# train_l = []
# val_l = []

# %%
from tqdm import tqdm
from matplotlib import pyplot as plt

# train_l = []
# val_l = []

for epoch in range(n_epochs):
    if (epoch % 10 == 0 and epoch > 0):
        eta.set_value(lasagne.utils.floatX(eta.get_value() / 10))
    train_loss=0
    for _ in tqdm(range(n_batches_per_epoch)):
        train_loss += train_step(*generate_batch(img_codes,captions,batch_size))
    train_loss /= n_batches_per_epoch
    
    val_loss=0
    for _ in range(n_validation_batches):
        val_loss += val_step(*generate_batch(img_codes,captions,batch_size))
    val_loss /= n_validation_batches
    
    train_l += [train_loss]
    val_l += [val_loss]
    
    plt.plot(train_l)
    plt.plot(val_l)
    plt.show()
    
    print('\nEpoch: {}, train loss: {}, val loss: {}'.format(epoch, train_loss, val_loss))
    send('\n Stepa: Epoch: {}, train loss: {}, val loss: {}'.format(epoch, train_loss, val_loss))

print("Finish :)")
# Out:
# 100%|██████████| 10/10 [00:14<00:00,  1.48s/it]
# Epoch: 0, train loss: 0.38272114396095275, val loss: 0.3408735811710358
# 100%|██████████| 10/10 [00:15<00:00,  1.45s/it]
# Epoch: 1, train loss: 0.3588563233613968, val loss: 0.3500092089176178
# 100%|██████████| 10/10 [00:14<00:00,  1.58s/it]
# Epoch: 2, train loss: 0.3498427927494049, val loss: 0.3394238352775574
# 100%|██████████| 10/10 [00:12<00:00,  1.21s/it]
# Epoch: 3, train loss: 0.33686942160129546, val loss: 0.34687567949295045
# 100%|██████████| 10/10 [00:13<00:00,  1.37s/it]
# Epoch: 4, train loss: 0.33748866319656373, val loss: 0.32482396960258486
# 100%|██████████| 10/10 [00:13<00:00,  1.33s/it]
# Epoch: 5, train loss: 0.3241789698600769, val loss: 0.3336469829082489
# 100%|██████████| 10/10 [00:12<00:00,  1.19s/it]
# Epoch: 6, train loss: 0.31547272503376006, val loss: 0.3112733244895935
# 100%|██████████| 10/10 [00:12<00:00,  1.26s/it]
# Epoch: 7, train loss: 0.3113073408603668, val loss: 0.3046118378639221
# ...

# %%
# Out:
# array(1.0000001111620804e-06, dtype=float32)

# %% [markdown]
# ### apply trained model

# %%
plt.plot(train_l)
plt.plot(val_l)
plt.show()

# %%
#the same kind you did last week, but a bit smaller
from pretrained_lenet2 import build_model,preprocess,MEAN_VALUES
# build googlenet
lenet = build_model()

#load weights
lenet_weights = pickle.load(open('data/blvc_googlenet.pkl', 'rb'), encoding='latin1')['param values']
set_all_param_values(lenet["prob"], lenet_weights)

#compile get_features
cnn_input_var = lenet['input'].input_var
cnn_feature_layer = lenet['loss3/classifier']
get_cnn_features = theano.function([cnn_input_var], lasagne.layers.get_output(cnn_feature_layer))

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

#sample image
img = plt.imread('data/Dog-and-Cat.jpg')
img = preprocess(img)
# Out:
# /usr/local/lib/python3.5/dist-packages/skimage/transform/_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "

# %%
#deprocess and show, one line :)
from pretrained_lenet2 import MEAN_VALUES
plt.imshow(np.transpose((img[0] + MEAN_VALUES)[::-1],[1,2,0]).astype('uint8'))

# %% [markdown]
# ## Generate caption

# %%
last_word_probas_det = get_output(predicted_probabilities,deterministic=False)[:,-1]

get_probs = theano.function([image_vectors,sentences], last_word_probas_det)

#this is exactly the generation function from week5 classwork,
#except now we condition on image features instead of words
def generate_caption(image,caption_prefix = ("START",),t=1,sample=True,max_len=100):
    image_features = get_cnn_features(image)
    caption = list(caption_prefix)
    for _ in range(max_len):
        
        next_word_probs = get_probs(image_features,as_matrix([caption]) ).ravel()
        #apply temperature
        next_word_probs = next_word_probs**t / np.sum(next_word_probs**t)

        if sample:
            next_word = np.random.choice(vocab,p=next_word_probs) 
        else:
            next_word = vocab[np.argmax(next_word_probs)]

        caption.append(next_word)

        if next_word=="#END#":
            break
            
    return caption

# %%
import requests
def send(text):
    requests.get("https://api.telegram.org/bot224136417:AAGJ2kKaoPiiksBVJ-8AslDTavFDL6btqqE/sendMessage?chat_id=52840743&text=%s" % text)
    requests.get("https://api.telegram.org/bot224136417:AAGJ2kKaoPiiksBVJ-8AslDTavFDL6btqqE/sendMessage?chat_id=78426908&text=%s" % text)

# %%
plt.imshow(np.transpose((img[0] + MEAN_VALUES)[::-1],[1,2,0]).astype('uint8'))
for i in range(10):
    print(' '.join(generate_caption(img,t=1.)[1:-1]))
    print()
# Out:
# older wicker four elderly clay door shower mustache blue a suit tan horse dog featured band dirt tiled her remote shades peer bare dining desk plaid elderly goofing empty business leafy cellular one herd t cast his concrete fenced baseball parking group an blurry birthday electronic messy stars a video gravel dressed brown bar outstretched game tea
#
# a tiled tooth pink fish baseball compete owner doubles graffiti atv covered front completely the elderly ceiling local cop 2 top of jeans shorts glasses horses 3 serve front front baseball stage part lemons theater open one nighttime tin a muddy exercise tying print strolling licks greasy formation against a scrambled a grassy uniform winds exiting center living blue hotel suit men backed own portion a elephants perched blurred baking feeds top approaches shorts he pieces produce hold interior doubles striped softball computers plastic silver ages best picture top approaching horse waves
#
# ...

# %% [markdown]
# Что-то пошло совсем не так.

# %% [markdown]
# # Bonus Part
# - Use ResNet Instead of GoogLeNet
# - Use W2V as embedding
# - Use Attention :)

# %%
words.count('dog')
# Out:
# 18839

# %% [markdown]
# # Pass Assignment https://goo.gl/forms/2qqVtfepn0t1aDgh1
